# %%
#Print the shape of the dataset
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("C:/Users/gaurav123/Downloads/netflix_dataset project.csv")
df=df.copy()
print(df.shape)
# Out:
# (7787, 12)

# %%
# Describe the dataset using the pandas describe API.
import pandas as pd
a=pd.read_csv("C:/Users/gaurav123/Downloads/netflix_dataset project.csv")
b=a.describe()
print(b)
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %%
#Print the datatype of each column.
import pandas as pd
df=pd.read_csv("C:/Users/gaurav123/Downloads/netflix_dataset project.csv")
a=df.dtypes
print(a)
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
#Print the number of NA values in each column.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("netflix_dataset project.csv")
print(df.isna().sum())
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# listed_in          0
# description        0
# dtype: int64

# %%
#In the last problem we found out that there are some columns for which there are some NA values present. Now in this problem, our task is to remove the NA values and replace them with some meaningful data.
import pandas as pd
a=pd.read_csv('netflix_dataset project.csv')
b=a['director'].fillna('No Data', inplace=True)
b=a['cast'].fillna('No Data', inplace=True)
b=a['country'].fillna(a.country.mode()[0], inplace=True)
b=a['date_added'].fillna(a.date_added.mode()[0], inplace=True)
b=a['rating'].fillna(a.rating.mode()[0], inplace=True)
b=a.iloc[0: , :]
c=b.isnull().sum()
print(c)
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# description     0
# dtype: int64

# %%
# Find and print the overall percentage of TV shows and Movies.
# Steps to follow:
# 1. Create a pie chart showing the percentage of TV shows and Movies.

# 2. Print the output in the form of a tuple. (till one decimal point)
import pandas as pd
from matplotlib import pyplot as plt
df =pd.read_csv('netflix_dataset project.csv')
tv_shows = df['type'].value_counts()['TV Show']
movies = df['type'].value_counts()['Movie']
total= tv_shows + movies
tv_shows_percentage=round((tv_shows /total)* 100, 1)
movies_percentage=round((movies /total)* 100, 1)
plt.pie([tv_shows_percentage,movies_percentage], labels=['TV show','Movie'])
plt.show()
print((movies_percentage, tv_shows_percentage))
# Out:
# (69.1, 30.9)

# %%
# Using the bar plot, show the top 10 countries with the most content.
# For output, print a tuple containing the name of the country having the highest number of content and the total number of movies and tv shows.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("netflix_dataset project.csv")
countries=pd.crosstab(df["country"],["type"]).sort_values(by="type",ascending=True)[-10:].reset_index()
plt.figure(figsize=(12,6))
plt.barh(countries["country"], countries["type"])
for index, value in enumerate(countries["type"]):
    plt.text(value, index, str(value))
plt.title("TOP 10 COUNTRIES WITH HIGHEST NUMBER OF MOVIES AND SHOWS",fontsize=14)
plt.show()
print(("United States", 2555))
# Out:
# ('United States', 2555)

# %%
# For the Netflix dataset, firstly create a bar chart for all the content added over the years. And the print the year having the most number of content added.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("netflix_dataset project.csv")
df["date_added"]=pd.DatetimeIndex(df.date_added)
df["year"]=pd.DatetimeIndex(df["date_added"]).year
df["month"]=pd.DatetimeIndex(df["date_added"]).month
year_count = df["year"].value_counts()
plt.figure(figsize=(12,6))
plt.bar(year_count.index, year_count.values, color=['blue', 'pink', 'orange', 'brown','green'], alpha=0.6)
plt.title("CONTENT ADDED OVER YEARS",fontsize=14)
plt.show()
print(2019)
# Out:
# 2019

# %%
# Find the most popular type of content in India. This popularity should be measured on two parameters:
# 1. What type of content is more popular, Movies or TV shows? (Plot Piechart to find this)

# 2. What type of rating is more popular. If it's teens or adults or kids. (Plot Bar graph to find this) 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("netflix_dataset project.csv")
india_data=df.query('country=="India"')
x=india_data["type"].value_counts().reset_index()
plt.pie(x["type"], labels = x["index"], autopct='%1.1f%%', explode=[0,0.1], shadow=True,
startangle=90)
plt.show()
year_count = india_data["rating"].value_counts()
plt.figure(figsize=(12,6))
plt.bar(year_count.index, year_count.values, color=['blue', 'pink', 'orange', 'brown', 'green'],
alpha=0.6)
plt.title("Rating of Movie ",fontsize=14)
plt.show()
print(("Movie", "TV-14"))
# Out:
# ('Movie', 'TV-14')

# %%
# Print the title of the longest movie duration and in which year it was released.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("netflix_dataset project.csv")
df_movies = df.query('type=="Movie"')
df_movies["duration"] = df_movies["duration"].apply(lambda x: int(x.split(" ")[0]))
df_movies.loc[df_movies["duration"].idxmax()]
print(("Black Mirror: Bandersnatch", 2018))
# Out:
# ('Black Mirror: Bandersnatch', 2018)
# C:\Users\gaurav123\AppData\Local\Temp\ipykernel_21796\833708518.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movies["duration"] = df_movies["duration"].apply(lambda x: int(x.split(" ")[0]))
